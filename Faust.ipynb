# %% [markdown]
# ## Welcome in the Faust in Julia tutorial !

# %% [markdown]
# First you'll have to install the Faust package with:

# %%
import Pkg; Pkg.add(url="https://github.com/sletz/Faust.jl")

# %% [markdown]
# Then using it:

# %%
using Faust
